# %%
from basicfunc import get_spectral
x = get_spectral("frt00003621_07_if166l_E_-97.60818_N_24.87141.csv")
# Out:
# Function: Spectral Plot
#
# File name
# frt00003621_07_if166l_E_-97.60818_N_24.87141.csv
#
# ...

# %%
from basicfunc import get_spectral
x = get_spectral("frt00003621_07_if166l_E_-97.66144_N_24.81565.csv")
# Out:
# Function: Spectral Plot
#
# File name
# frt00003621_07_if166l_E_-97.66144_N_24.81565.csv
#
# ...

# %%
from basicfunc import standardization
x = standardization("frt00003621_07_if166l_E_-97.60818_N_24.87141.csv", "frt00003621_07_if166l_E_-97.69471_N_24.88780.csv")#,"frt00003621_07_if166l_E_-97.66144_N_24.81565.csv")
# Out:
# Function: Spectral Standardization
#
# File name
# frt00003621_07_if166l_E_-97.60818_N_24.87141.csv -Base-
# frt00003621_07_if166l_E_-97.69471_N_24.88780.csv -2nd-
#
# 854
# 854
#
#
# y: reflectance -base-
# [0.23934677 0.2387069  0.23399156 0.2350816  0.23489128 0.23291151
#  0.23361053 0.2350479  0.23457544 0.23427933 0.23374824 0.23505825
#  0.2361436  0.23792356 0.23855512 0.23734571 0.23718263 0.2374533
#  0.23772936 0.23790352 0.23861794 0.2395358  0.240313   0.24053612
#  0.24083242 0.23933867 0.23995502 0.24169019 0.23867814 0.23530193
#  0.23721232 0.23670933 0.23657453 0.23857313 0.24033485 0.24140333
#  0.24231814 0.24168803 0.24234284 0.2445216  0.24423452 0.2437918
#  0.24415472 0.24438804 0.24576585 0.24433993 0.24271297 0.24623542
#  0.24565166 0.24519593 0.2452591  0.24506053 0.24465476 0.24356392
#  0.24272424 0.24357386 0.24346402 0.24457788 0.2457822  0.24588186
#  0.24654873 0.2479095  0.24955772 0.24162005 0.2299672  0.23019913
# ...

# %%
from basicfunc import moving_avg
x = moving_avg("frt00003621_07_if166l_E_-97.60818_N_24.87141.csv", 6)
# Out:
# Function: Spectral Moving Average
#
# File name
# frt00003621_07_if166l_E_-97.60818_N_24.87141.csv
#
# x: wavelength
# [1.01445 1.021   1.02755 1.0341  1.04065 1.0472  1.05375 1.0603  1.06685
#  1.07341 1.07996 1.08651 1.09307 1.09962 1.10617 1.11273 1.11928 1.12584
#  1.13239 1.13895 1.14551 1.15206 1.15862 1.16518 1.17173 1.17829 1.18485
#  1.19141 1.19797 1.20453 1.21109 1.21765 1.22421 1.23077 1.23733 1.24389
#  1.25045 1.25701 1.26357 1.27014 1.2767  1.28326 1.28983 1.29639 1.30295
#  1.30952 1.31608 1.32265 1.32921 1.33578 1.34234 1.34891 1.35548 1.36205
#  1.36861 1.37518 1.38175 1.38832 1.39489 1.40145 1.40802 1.41459 1.42116
#  1.42773 1.43431 1.44088 1.44745 1.45402 1.46059 1.46716 1.47374 1.48031
#  1.48688 1.49346 1.50003 1.50661 1.51318 1.51976 1.52633 1.53291 1.53948
#  1.54606 1.55264 1.55921 1.56579 1.57237 1.57895 1.58552 1.5921  1.59868
#  1.60526 1.61184 1.61842 1.625   1.63158 1.63816 1.64474 1.65133 1.65791
# ...

# %%
from basicfunc import standardization
x = standardization("frt00003621_07_if166l_E_-97.66144_N_24.81565.csv","frt00003621_07_if166l_E_-97.60818_N_24.87141.csv")
# Out:
# Function: Spectral Standardization
#
# File name
# frt00003621_07_if166l_E_-97.66144_N_24.81565.csv -Base-
# frt00003621_07_if166l_E_-97.60818_N_24.87141.csv -2nd-
#
# 864
# 854
#
#
# [257 258 259 260 261]
# <class 'numpy.ndarray'>
# [0.23934677 0.2387069  0.23399156 0.2350816  0.23489128 0.23291151
#  0.23361053 0.2350479  0.23457544 0.23427933 0.23374824 0.23505825
#  0.2361436  0.23792356 0.23855512 0.23734571 0.23718263 0.2374533
#  0.23772936 0.23790352 0.23861794 0.2395358  0.240313   0.24053612
#  0.24083242 0.23933867 0.23995502 0.24169019 0.23867814 0.23530193
#  0.23721232 0.23670933 0.23657453 0.23857313 0.24033485 0.24140333
#  0.24231814 0.24168803 0.24234284 0.2445216  0.24423452 0.2437918
#  0.24415472 0.24438804 0.24576585 0.24433993 0.24271297 0.24623542
#  0.24565166 0.24519593 0.2452591  0.24506053 0.24465476 0.24356392
#  0.24272424 0.24357386 0.24346402 0.24457788 0.2457822  0.24588186
#  0.24654873 0.2479095  0.24955772 0.24162005 0.2299672  0.23019913
# ...

# %%
from basic_func import standardization, spectralplot
x = standardization("frt00003621_07_if166l_E_-97.66144_N_24.81565.csv","frt00003621_07_if166l_E_-97.60818_N_24.87141.csv")
spectralplot(x)
# Out:
# No.1
# [1.01445 1.021   1.02755 1.0341  1.04065 1.0472  1.05375 1.0603  1.06685
#  1.07341 1.07996 1.08651 1.09307 1.09962 1.10617 1.11273 1.11928 1.12584
#  1.13239 1.13895 1.14551 1.15206 1.15862 1.16518 1.17173 1.17829 1.18485
#  1.19141 1.19797 1.20453 1.21109 1.21765 1.22421 1.23077 1.23733 1.24389
#  1.25045 1.25701 1.26357 1.27014 1.2767  1.28326 1.28983 1.29639 1.30295
#  1.30952 1.31608 1.32265 1.32921 1.33578 1.34234 1.34891 1.35548 1.36205
#  1.36861 1.37518 1.38175 1.38832 1.39489 1.40145 1.40802 1.41459 1.42116
#  1.42773 1.43431 1.44088 1.44745 1.45402 1.46059 1.46716 1.47374 1.48031
#  1.48688 1.49346 1.50003 1.50661 1.51318 1.51976 1.52633 1.53291 1.53948
#  1.54606 1.55264 1.55921 1.56579 1.57237 1.57895 1.58552 1.5921  1.59868
#  1.60526 1.61184 1.61842 1.625   1.63158 1.63816 1.64474 1.65133 1.65791
#  1.66449 1.67107 1.67766 1.68424 1.69082 1.69741 1.70399 1.71058 1.71716
#  1.72375 1.73033 1.73692 1.74351 1.75009 1.75668 1.76327 1.76985 1.77644
# ...

# %%
from basic_func import standardization,spectralplot
x = standardization("frt00003621_07_if166l_E_-97.60818_N_24.87141.csv", "frt00003621_07_if166l_E_-97.69471_N_24.88780.csv")#,"frt00003621_07_if166l_E_-97.66144_N_24.81565.csv")
spectralplot(x)
# Out:
# No.1
# [1.01445 1.021   1.02755 1.0341  1.04065 1.0472  1.05375 1.0603  1.06685
#  1.07341 1.07996 1.08651 1.09307 1.09962 1.10617 1.11273 1.11928 1.12584
#  1.13239 1.13895 1.14551 1.15206 1.15862 1.16518 1.17173 1.17829 1.18485
#  1.19141 1.19797 1.20453 1.21109 1.21765 1.22421 1.23077 1.23733 1.24389
#  1.25045 1.25701 1.26357 1.27014 1.2767  1.28326 1.28983 1.29639 1.30295
#  1.30952 1.31608 1.32265 1.32921 1.33578 1.34234 1.34891 1.35548 1.36205
#  1.36861 1.37518 1.38175 1.38832 1.39489 1.40145 1.40802 1.41459 1.42116
#  1.42773 1.43431 1.44088 1.44745 1.45402 1.46059 1.46716 1.47374 1.48031
#  1.48688 1.49346 1.50003 1.50661 1.51318 1.51976 1.52633 1.53291 1.53948
#  1.54606 1.55264 1.55921 1.56579 1.57237 1.57895 1.58552 1.5921  1.59868
#  1.60526 1.61184 1.61842 1.625   1.63158 1.63816 1.64474 1.65133 1.65791
#  1.66449 1.67107 1.67766 1.68424 1.69082 1.69741 1.70399 1.71058 1.71716
#  1.72375 1.73033 1.73692 1.74351 1.75009 1.75668 1.76327 1.76985 1.77644
# ...

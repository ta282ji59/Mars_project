# %%
import sys
import numpy as np
import pandas as pd
import bottleneck as bn
import matplotlib.pyplot as plt
import csv

# %%
from basicfunc import moving_avg
a = moving_avg("I52359002SNU_E_-73.49334_N_30.73279.csv",3)
# Out:
# Function: Spectral Moving Average
#
# File name
# I52359002SNU_E_-73.49334_N_30.73279.csv
#
# x: wavelength
# [ 6.78  6.78  7.93  8.56  9.35 10.21 11.04 11.79 12.57 14.88]
#
# y: reflectance
# [0.0007549  0.00076933 0.00146148 0.00165143 0.0018937  0.00212045
#  0.00231332 0.00248888 0.00247696 0.00053708]
#
# y: reflectance  -Moving Average-
# [       nan        nan 0.00099524 0.00129408 0.00166887 0.00188853
#  0.00210916 0.00230755 0.00242639 0.00183431]

# %%
print(a)

array = iter(a)
count = 1
for x, y in zip(array, array):
    num = str(count)
    lbl = "No."+num
    plt.plot(x, y, marker=".", label=lbl)
    print(lbl)
    print(x)
    print(y)
    count += 1
plt.legend()
plt.xlabel('Wavelength [nm]')
plt.ylabel('Reflentance')
plt.title('Spectral')
# Out:
# (array([ 6.78,  6.78,  7.93,  8.56,  9.35, 10.21, 11.04, 11.79, 12.57,
#        14.88]), array([0.0007549 , 0.00076933, 0.00146148, 0.00165143, 0.0018937 ,
#        0.00212045, 0.00231332, 0.00248888, 0.00247696, 0.00053708]), array([ 6.78,  6.78,  7.93,  8.56,  9.35, 10.21, 11.04, 11.79, 12.57,
#        14.88]), array([       nan,        nan, 0.00099524, 0.00129408, 0.00166887,
#        0.00188853, 0.00210916, 0.00230755, 0.00242639, 0.00183431]))
# No.1
# [ 6.78  6.78  7.93  8.56  9.35 10.21 11.04 11.79 12.57 14.88]
# [0.0007549  0.00076933 0.00146148 0.00165143 0.0018937  0.00212045
#  0.00231332 0.00248888 0.00247696 0.00053708]
# No.2
# [ 6.78  6.78  7.93  8.56  9.35 10.21 11.04 11.79 12.57 14.88]
# [       nan        nan 0.00099524 0.00129408 0.00166887 0.00188853
#  0.00210916 0.00230755 0.00242639 0.00183431]
# Text(0.5, 1.0, 'Spectral')
